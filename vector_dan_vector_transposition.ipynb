# %%
import numpy as np

# %%
# 1.buat vector x dengan ukuran 3x1
x = np.array([13, 8, 6]) # type argument is optional, e.g.: dtype=np.float16
x
# Out:
# array([13,  8,  6])

# %%
# hitung panjang vector x
len(x)
# Out:
# 3

# %%
# tampilkan ukuran vector x
x.shape
# Out:
# (3,)

# %%
# tampilkan tipe data dari vector x
type(x)
# Out:
# numpy.ndarray

# %%
# akses elemen pertama dari vector x
x[0] # zero-indexed
# Out:
# np.int64(13)

# %%
# tampilkan tipe data elemen pertama dari vector x
type(x[0])
# Out:
# numpy.int64

# %%
# lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = x.T
x_t
# Out:
# array([13,  8,  6])

# %%
# tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %%
y = np.array([[13, 8, 6]])
y
# Out:
# array([[13,  8,  6]])

# %%
# lakukan transpose pada vector y dan simpan pada variabel y_t
y_t = y.T
y_t
# Out:
# array([[13],
#        [ 8],
#        [ 6]])

# %%
# tampilkan ukuran dari vector x_t
y_t.shape
# Out:
# (3, 1)

# %%
# lakukan soal nomor 2 menggunakan pytorch dan tensorflow
import torch
import tensorflow as tf

# %%
x_pt = torch.tensor([13, 8, 6])
x_pt
# Out:
# tensor([13,  8,  6])

# %%
x_tf = tf.Variable([13, 8, 6])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([13,  8,  6], dtype=int32)>
